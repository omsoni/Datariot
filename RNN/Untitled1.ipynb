# %%
import matplotlib.pyplot as plt
from numpy import *
## Ford LSTM
epochs = [0,5,10,15,20,25,30,35,40,45,50,55]
trainMSE = [6.526543,1.283074,1.288437,1.268608,1.268204,1.26799,1.268371,1.274781,1.269305,1.271329,1.269844,1.267253]
testMSE = [7.577332,1.274848,1.28685,1.264416,1.263397,1.263624,1.263835,1.272504,1.264206,1.266648,1.265614,1.262558]

[a,b] = plt.plot(epochs, trainMSE, 'r--', epochs, testMSE, 'g--')
plt.title("Basic LSTM RNN for Ford Stock Prediction")
plt.legend([a,b], ["TrainingMSE" , "TestMSE"], loc=1)
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.show()

# %%
# OEPC BasicRNN
epochs = [0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900]
trainMSE = [48644.875,385.70923,145.65506,108.33204,85.62118,73.62356,65.95521,61.379658,58.812187,57.417,56.668575,56.27882,56.16231,56.14428,55.86698,56.15034,55.651405,55.591637,56.09038,55.506107]
testMSE = [386.873608,24.272696,25.469177,25.22323,24.313774,23.712397,23.326204,23.085167,22.950315,22.876648,22.837332,22.817705,22.805895,22.796665,22.790823,22.78954,22.783167,22.77944,22.78148,22.776001]
plt.title("Basic RNN for OPEC/ORB Price Prediction")
[a,b] = plt.plot(epochs, trainMSE, 'r--', epochs, testMSE, 'g--')
plt.legend([a,b], ["TrainingMSE" , "TestMSE"], loc=1)
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.show()
